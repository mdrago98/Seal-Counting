# %% [markdown]
# # Understanding Resnet
#
# Training Deep neural networks suffers from a number of problems namely:
#
# - The vanishing gradient problem (solved using RelU and Batch Normalisation)
# - Degradation
#
# The authors noted that by adding additional layers the training errors increased and accuracy decreased.
# The problem couldn't be attributed to overfitting due to high degree of training error.
#
#
# ![degradation](degradation.png)
#
# Their research shows that deep neural network architectures fail to recognise the Identity function.
# The ResNet architecture aims to specifically

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import datetime as dt


config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.9

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
# %load_ext tensorboard

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(64).shuffle(10000)
train_dataset = train_dataset.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y))
train_dataset = train_dataset.map(lambda x, y: (tf.image.central_crop(x, 0.75), y))
train_dataset = train_dataset.map(lambda x, y: (tf.image.random_flip_left_right(x), y))
train_dataset = train_dataset.repeat()
valid_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(5000).shuffle(10000)
valid_dataset = valid_dataset.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y))
valid_dataset = valid_dataset.map(lambda x, y: (tf.image.central_crop(x, 0.75), y))
valid_dataset = valid_dataset.repeat()

# %% [markdown]
# Define the resnet residual block using the functional api.
# ![degradation](identity.png)

# %%
def res_net_block(input, filters, conv_size):
    x = keras.layers.Conv2D(filters, conv_size, activation='relu', padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(filters, conv_size, activation=None, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([x, input])
    x = layers.Activation('relu')(x)
    return x

def non_res_block(input_data, filters, conv_size):
  x = layers.Conv2D(filters, conv_size, activation='relu', padding='same')(input_data)
  x = layers.BatchNormalization()(x)
  x = layers.Conv2D(filters, conv_size, activation='relu', padding='same')(x)
  x = layers.BatchNormalization()(x)
  return x

# %% [markdown]
# Define the model:

# %%
inputs = keras.Input(shape=(24, 24, 3))
x = layers.Conv2D(32, 3, activation='relu')(inputs)
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.MaxPooling2D(3)(x)
num_res_net_blocks = 10
for i in range(num_res_net_blocks):
    x = res_net_block(x, 64, 3)
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation='softmax')(x)
res_net_model = keras.Model(inputs, outputs)

# %%
callbacks = [
  # Write TensorBoard logs to `./logs` directory
  keras.callbacks.TensorBoard(log_dir='./logs/fit/{}'.format(dt.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")), write_images=True),
]
res_net_model.compile(optimizer=keras.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['acc'])
res_net_model.fit(train_dataset, epochs=30, steps_per_epoch=195,
          validation_data=valid_dataset,
          validation_steps=3, callbacks=callbacks)
# Out:
# Epoch 1/30
# 195/195 [==============================] - 5s 24ms/step - loss: 1.9927 - acc: 0.2450 - val_loss: 2.5268 - val_acc: 0.1131
# Epoch 2/30
# 195/195 [==============================] - 4s 22ms/step - loss: 1.7042 - acc: 0.3646 - val_loss: 2.0010 - val_acc: 0.2587
# Epoch 3/30
# 195/195 [==============================] - 4s 20ms/step - loss: 1.5392 - acc: 0.4434 - val_loss: 2.1131 - val_acc: 0.2997
# Epoch 4/30
# 195/195 [==============================] - 4s 20ms/step - loss: 1.4387 - acc: 0.4873 - val_loss: 1.9743 - val_acc: 0.3177
# Epoch 5/30
# 195/195 [==============================] - 4s 21ms/step - loss: 1.3688 - acc: 0.5186 - val_loss: 1.5178 - val_acc: 0.4811
# Epoch 6/30
# 195/195 [==============================] - 4s 21ms/step - loss: 1.3073 - acc: 0.5443 - val_loss: 2.0004 - val_acc: 0.4220
# Epoch 7/30
# 195/195 [==============================] - 4s 21ms/step - loss: 1.2390 - acc: 0.5668 - val_loss: 1.7289 - val_acc: 0.4603
# Epoch 8/30
# 195/195 [==============================] - 4s 21ms/step - loss: 1.2079 - acc: 0.5771 - val_loss: 1.3259 - val_acc: 0.5367
# Epoch 9/30
# 195/195 [==============================] - 4s 21ms/step - loss: 1.1740 - acc: 0.5884 - val_loss: 1.1663 - val_acc: 0.5925
# Epoch 10/30
# 195/195 [==============================] - 4s 20ms/step - loss: 1.1197 - acc: 0.6106 - val_loss: 1.4526 - val_acc: 0.5156
# Epoch 11/30
# 195/195 [==============================] - 4s 20ms/step - loss: 1.0984 - acc: 0.6148 - val_loss: 1.3548 - val_acc: 0.5314
# Epoch 12/30
# 195/195 [==============================] - 4s 21ms/step - loss: 1.0667 - acc: 0.6288 - val_loss: 1.2423 - val_acc: 0.5839
# Epoch 13/30
# 195/195 [==============================] - 4s 21ms/step - loss: 1.0312 - acc: 0.6466 - val_loss: 1.2861 - val_acc: 0.5526
# Epoch 14/30
# 195/195 [==============================] - 4s 20ms/step - loss: 1.0093 - acc: 0.6495 - val_loss: 1.0381 - val_acc: 0.6340
# Epoch 15/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9965 - acc: 0.6514 - val_loss: 1.4310 - val_acc: 0.5455
# Epoch 16/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9723 - acc: 0.6671 - val_loss: 0.9828 - val_acc: 0.6561
# Epoch 17/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9332 - acc: 0.6797 - val_loss: 1.0296 - val_acc: 0.6394
# Epoch 18/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9218 - acc: 0.6843 - val_loss: 1.0479 - val_acc: 0.6402
# Epoch 19/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9335 - acc: 0.6774 - val_loss: 1.0874 - val_acc: 0.6333
# Epoch 20/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8968 - acc: 0.6936 - val_loss: 1.1664 - val_acc: 0.6079
# Epoch 21/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8584 - acc: 0.7070 - val_loss: 1.0178 - val_acc: 0.6611
# Epoch 22/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8767 - acc: 0.7005 - val_loss: 0.9468 - val_acc: 0.6741
# Epoch 23/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8697 - acc: 0.7014 - val_loss: 1.0192 - val_acc: 0.6526
# Epoch 24/30
# 195/195 [==============================] - 4s 22ms/step - loss: 0.8509 - acc: 0.7066 - val_loss: 0.9954 - val_acc: 0.6647
# Epoch 25/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8278 - acc: 0.7153 - val_loss: 1.0991 - val_acc: 0.6294
# Epoch 26/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8192 - acc: 0.7204 - val_loss: 0.9373 - val_acc: 0.6781
# Epoch 27/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8134 - acc: 0.7185 - val_loss: 0.9456 - val_acc: 0.6898
# Epoch 28/30
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8051 - acc: 0.7290 - val_loss: 1.0585 - val_acc: 0.6570
# Epoch 29/30
# 195/195 [==============================] - 4s 22ms/step - loss: 0.7648 - acc: 0.7446 - val_loss: 0.9828 - val_acc: 0.6619
# Epoch 30/30
# 195/195 [==============================] - 4s 20ms/step - loss: 0.7716 - acc: 0.7377 - val_loss: 1.0319 - val_acc: 0.6447

# %%
# %tensorboard --logdir ./logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 4903), started 0:05:46 ago. (Use '!kill 4903' to kill it.)
#       <iframe id="tensorboard-frame-d252597e8351dcba" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d252597e8351dcba");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
